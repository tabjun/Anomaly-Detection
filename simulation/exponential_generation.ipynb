# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(5)

data = np.random.exponential(scale=0.05, size = 10000)

print(data[:5]);print(min(data));print(max(data))
# Out:
# [0.012551   0.10229349 0.0115789  0.1254257  0.0335117 ]
# 7.341021898793489e-06
# 0.5389041803700022

# %%
sns.displot(data, kind='kde')
plt.show()

# %%
pd.Series(data).plot()
# Out:
# <Axes: >
