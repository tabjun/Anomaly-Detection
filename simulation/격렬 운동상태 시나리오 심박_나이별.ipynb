# %%
import pandas as pd
import numpy as np
import random
import seaborn as sns

# %%
# update_time 데이터프레임 생성, 10분 단위로 생성
date = pd.date_range('2023-10-01 00:00:00', periods=1350, freq='10T')

# 임시 데이터 만들기
q1 = pd.DataFrame()
q1['a'] = 1

# 데이터 합치기
q = pd.DataFrame(q1, index = date)

# datetimeindex를 변수로 변경
q.reset_index(drop=False, inplace=True)

# 필요없는 변수 삭제
del q['a']

# 변수명 변경
q.rename(columns = {'index' : 'update_time'}, inplace = True)
q
# Out:
#              update_time
# 0    2023-10-01 00:00:00
# 1    2023-10-01 00:10:00
# 2    2023-10-01 00:20:00
# 3    2023-10-01 00:30:00
# 4    2023-10-01 00:40:00
# ...                  ...
# 1345 2023-10-10 08:10:00
# 1346 2023-10-10 08:20:00
# 1347 2023-10-10 08:30:00
# 1348 2023-10-10 08:40:00
# 1349 2023-10-10 08:50:00
#
# [1350 rows x 1 columns]

# %% [markdown]
# # 격렬한 운동 데이터 만들기

# %% [markdown]
# ##### 20대 만들기

# %%
178+80
258/2
# Out:
# 129.0

# %%
print(pd.DataFrame(np.random.normal(129, 24, 1350)).describe())
r_data = np.random.normal(129, 24, 1350)

r = pd.DataFrame()
r['a'] = r_data
print(len(r[(r['a']<80)|(r['a']>178)]))
# Out:
#                  0
# count  1350.000000
# mean    129.148060
# std      24.624631
# min      57.844549
# 25%     111.802549
# 50%     129.243770
# 75%     145.301939
# max     216.306125
# 56

# %%
나이_20 = pd.DataFrame()

# 각 변수 생성과 데이터프레임 병합
for i in range(1, 1001):
   # 각 변수별로 다른 random seed 설정
   np.random.seed(i)
   
   # 정규분포 랜덤 추출
   # 일주일치 1008개
   r_data = np.random.normal(129, 24, 1350) 
   r_data = r_data.astype(int)    
   
   # 변수명 생성 
   var_name = f'heart_rate{i}'
   
   # 데이터프레임에 변수 추가
   나이_20[var_name] = r_data
   
   # event로 변수 생성
   나이_20[f'event{i}'] = 나이_20[var_name].apply(lambda x: 1 if (x < 80 )|(x > 178) else 0 if 80 <= x <= 178 else x)
   
   # 변수(본포{i})마다 행 순서 바꾸기
   np.random.seed(i)
   나이_20 = 나이_20.sample(frac=1)
   
print(나이_20.shape)
# Out:
# (1350, 2000)

# %%
# for i in range(1,1001):
#     sns.kdeplot(젊음[f'heart_rate{i}'])

# %%
나이_20.set_index(q['update_time'], inplace=True)
나이_20[:5]
# Out:
#                      heart_rate1  event1  heart_rate2  event2  heart_rate3  \
# update_time
# 2023-10-01 00:00:00          109       0          181       1          121
# 2023-10-01 00:10:00          103       0          105       0          175
# 2023-10-01 00:20:00          158       0          153       0          178
# 2023-10-01 00:30:00          140       0          115       0          145
# 2023-10-01 00:40:00          143       0          118       0          100
#
#                      event3  heart_rate4  event4  heart_rate5  event5  ...  \
# update_time                                                            ...
# 2023-10-01 00:00:00       0          122       0          167       0  ...
# 2023-10-01 00:10:00       0          158       0          165       0  ...
# 2023-10-01 00:20:00       0          143       0          131       0  ...
# 2023-10-01 00:30:00       0          131       0          124       0  ...
# ...

# %% [markdown]
# ##### 30대

# %%
75+169
244/2
# Out:
# 122.0

# %%
r_data = np.random.normal(122, 23, 1350)
print(pd.DataFrame(r_data).describe())

r = pd.DataFrame()
r['a'] = r_data
print(len(r[(r['a']<75)|(r['a']>169)]))
# Out:
#                  0
# count  1350.000000
# mean    123.044690
# std      23.197867
# min      36.418396
# 25%     107.345756
# 50%     122.717850
# 75%     138.358736
# max     193.274078
# 67

# %%
# 한 분포에서 추출하기
# train
나이_30 = pd.DataFrame()

# 각 변수 생성과 데이터프레임 병합
for i in range(1, 1001):
   # 각 변수별로 다른 random seed 설정
   np.random.seed(i)
   
   # 정규분포 랜덤 추출
   # 일주일치 1008개
   r_data = np.random.normal(122, 23, 1350) 
   r_data = r_data.astype(int)    
   
   # 변수명 생성 
   var_name = f'heart_rate{i}'
   
   # 데이터프레임에 변수 추가
   나이_30[var_name] = r_data
   
   # event로 변수 생성
   나이_30[f'event{i}'] = 나이_30[var_name].apply(lambda x: 1 if (x < 75 )|(x > 169) else 0 if 75 <= x <= 169 else x)
   
   # 변수(본포{i})마다 행 순서 바꾸기
   np.random.seed(i)
   나이_30 = 나이_30.sample(frac=1)
   
print(나이_30.shape)
# Out:
# (1350, 2000)

# %%
나이_30.set_index(q['update_time'], inplace=True)
나이_30[:5]
# Out:
#                      heart_rate1  event1  heart_rate2  event2  heart_rate3  \
# update_time
# 2023-10-01 00:00:00          103       0          172       1          115
# 2023-10-01 00:10:00           97       0           99       0          166
# 2023-10-01 00:20:00          150       0          145       0          169
# 2023-10-01 00:30:00          132       0          109       0          137
# 2023-10-01 00:40:00          135       0          111       0           94
#
#                      event3  heart_rate4  event4  heart_rate5  event5  ...  \
# update_time                                                            ...
# 2023-10-01 00:00:00       0          116       0          158       0  ...
# 2023-10-01 00:10:00       0          150       0          157       0  ...
# 2023-10-01 00:20:00       0          135       0          124       0  ...
# 2023-10-01 00:30:00       0          124       0          117       0  ...
# ...

# %% [markdown]
# ##### 40대

# %%
70+159
229/2
# Out:
# 114.5

# %%
r_data = np.random.normal(114.5, 22, 1350)
print(pd.DataFrame(r_data).describe())

r = pd.DataFrame()
r['a'] = r_data
print(len(r[(r['a']<70)|(r['a']>159)]))
# Out:
#                  0
# count  1350.000000
# mean    113.607951
# std      21.358468
# min      45.791844
# 25%     100.067937
# 50%     113.618516
# 75%     127.316364
# max     177.003772
# 55

# %%
# 한 분포에서 추출하기
# train
나이_40 = pd.DataFrame()

# 각 변수 생성과 데이터프레임 병합
for i in range(1, 1001):
   # 각 변수별로 다른 random seed 설정
   np.random.seed(i)
   
   # 정규분포 랜덤 추출
   # 일주일치 1008개
   r_data = np.random.normal(114.5, 22, 1350) 
   r_data = r_data.astype(int)    
   
   # 변수명 생성 
   var_name = f'heart_rate{i}'
   
   # 데이터프레임에 변수 추가
   나이_40[var_name] = r_data
   
   # event로 변수 생성
   나이_40[f'event{i}'] = 나이_40[var_name].apply(lambda x: 1 if (x < 70 )|(x > 159) else 0 if 70 <= x <= 159 else x)
   
   # 변수(본포{i})마다 행 순서 바꾸기
   np.random.seed(i)
   나이_40 = 나이_40.sample(frac=1)
   
print(나이_40.shape)
# Out:
# (1350, 2000)

# %%
나이_40.set_index(q['update_time'], inplace=True)
나이_40.index[:5]
# Out:
# DatetimeIndex(['2023-10-01 00:00:00', '2023-10-01 00:10:00',
#                '2023-10-01 00:20:00', '2023-10-01 00:30:00',
#                '2023-10-01 00:40:00'],
#               dtype='datetime64[ns]', name='update_time', freq=None)

# %% [markdown]
# ##### 50대

# %%
65+150
215/2
# Out:
# 107.5

# %%
r_data = np.random.normal(107.5, 20.5, 1350)
print(pd.DataFrame(r_data).describe())

r = pd.DataFrame()
r['a'] = r_data
print(len(r[(r['a']<65)|(r['a']>150)]))
# Out:
#                  0
# count  1350.000000
# mean    107.297758
# std      19.972795
# min      22.683270
# 25%      93.428469
# 50%     106.789993
# 75%     120.399644
# max     177.368296
# 46

# %%
# 한 분포에서 추출하기
# train
나이_50 = pd.DataFrame()

# 각 변수 생성과 데이터프레임 병합
for i in range(1, 1001):
   # 각 변수별로 다른 random seed 설정
   np.random.seed(i)
   
   # 정규분포 랜덤 추출
   # 일주일치 1008개
   r_data = np.random.normal(107.5, 20.5, 1350) 
   r_data = r_data.astype(int)    
   
   # 변수명 생성 
   var_name = f'heart_rate{i}'
   
   # 데이터프레임에 변수 추가
   나이_50[var_name] = r_data
   
   # event로 변수 생성
   나이_50[f'event{i}'] = 나이_50[var_name].apply(lambda x: 1 if (x < 65 )|(x > 150) else 0 if 65 <= x <= 150 else x)
   
   # 변수(본포{i})마다 행 순서 바꾸기
   np.random.seed(i)
   나이_50 = 나이_50.sample(frac=1)
   
print(나이_50.shape)

나이_50.set_index(q['update_time'], inplace=True)
나이_50[:5]
# Out:
# (1350, 2000)
#                      heart_rate1  event1  heart_rate2  event2  heart_rate3  \
# update_time
# 2023-10-01 00:00:00           91       0          152       1          101
# 2023-10-01 00:10:00           85       0           87       0          147
# 2023-10-01 00:20:00          132       0          128       0          149
# 2023-10-01 00:30:00          117       0           96       0          121
# 2023-10-01 00:40:00          119       0           98       0           82
#
#                      event3  heart_rate4  event4  heart_rate5  event5  ...  \
# update_time                                                            ...
# 2023-10-01 00:00:00       0          102       0          140       0  ...
# 2023-10-01 00:10:00       0          133       0          139       0  ...
# 2023-10-01 00:20:00       0          119       0          109       0  ...
# 2023-10-01 00:30:00       0          109       0          103       0  ...
# ...

# %%
나이_20.to_csv('../나이별/격렬_20_이상5.csv')
나이_30.to_csv('../나이별/격렬_30_이상5.csv')
나이_40.to_csv('../나이별/격렬_40_이상5.csv')
나이_50.to_csv('../나이별/격렬_50_이상5.csv')
