# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(5)

data = np.random.uniform(low=40, high=120, size = 10000)

sns.displot(data, kind='kde')

plt.show()
